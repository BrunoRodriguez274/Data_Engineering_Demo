# %% [markdown]
# # Secrets

# %% [markdown]
# How to create a secret
#
# * Create an scope
#
# * Create a secret using json notation
#
#
# databricks secrets put-secret --json '{
#   "scope": "<scope-name>",
#   "key": "<key-name>",
#   "string_value": "<secret>"
# }'

# %%
# databricks secrets put-secret --json '{
#   "scope": "<scope-name>",
#   "key": "<key-name>",
#   "string_value": "<secret>"
# }'

# %%
password = dbutils.secrets.get(scope = "mysql_momentum", key = "password")
password

# %%
password == "12345"

# %%
dbutils.secrets.listScopes
